# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives**
# - List popular languages for Data Science (Python, R, SQL, etc.)
# - Describe common data science tools (Open Source, Cloud-based, Commercial)
# - Explain how to use libraries, APIs, and datasets for analysis
# - Work with Jupyter Notebook and JupyterLab environments
# - Understand version control using Git and GitHub

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas – Dataframes, data cleaning, wrangling, and analysis
# 2. NumPy – Numerical computing, arrays, mathematical operations
# 3. Matplotlib – Core plotting library
# 4. Seaborn – Statistical visualisation built on Matplotlib
# 5. Plotly – Interactive charts and dashboards
# 6. Scikit-learn – Classical machine learning algorithms
# 7. TensorFlow – Deep learning framework
# 8. PyTorch – Deep learning and research-focused ML
# 9. dplyr – Core R package for data manipulation using a consistent grammar
# 10. tidyr – Reshaping and tidying messy datasets in R
# 11. data.table – High-performance data manipulation for large datasets in R
# 12. Caret (R) – Unified interface for training and tuning machine learning models

# %% [markdown]
# Data Science Tools
# 1. Jupyter Notebook / JupyterLab
# 2. RStudio
# 3. VS Code (Visual Studio Code)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
sample_1 = 200

# This will convert 200 minutes to hours by diving by 60
def convert_minutes_to_hours(minutes):
    hours = minutes / 60
    return hours

convert_minutes_to_hours(sample_1)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Lean Lerry Delgado

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
